# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.pyplot import figure

# %%
test = pd.read_csv('../data/AEIM373-object_data_test.csv')

# %%
x_y_coord = test[['XMin', 'XMax', 'YMin', 'YMax']]

# %%
x_y_coord['x'] = (x_y_coord['XMin'] + x_y_coord['XMax'])/2
x_y_coord['y'] = (x_y_coord['YMin'] + x_y_coord['YMax'])/2
# Out:
# /var/folders/gr/2g0jyzm95pd35p78f7612fdc0000gq/T/ipykernel_91433/1025837736.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_y_coord['x'] = (x_y_coord['XMin'] + x_y_coord['XMax'])/2
# /var/folders/gr/2g0jyzm95pd35p78f7612fdc0000gq/T/ipykernel_91433/1025837736.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_y_coord['y'] = (x_y_coord['YMin'] + x_y_coord['YMax'])/2

# %%
x_y_coord= x_y_coord[['x', 'y']]
x_y_coord
# Out:
#              x        y
# 0       5622.0   1096.0
# 1       5329.5   1096.5
# 2       5601.5   1097.0
# 3       5896.5   1096.5
# 4       5278.0   1095.5
# ...        ...      ...
# 270151  6970.5  16634.0
# 270152  6932.5  16630.5
# 270153  6995.0  16636.5
# 270154  7007.5  16643.5
# 270155  7119.5  16659.5
#
# [270156 rows x 2 columns]

# %%
x = x_y_coord['x']
y = x_y_coord['y']

figure(figsize=(50,50))
test_image = plt.scatter(x, y)
plt.savefig('test_image.png')
